# %%
# %pip install scipy.special
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 10.9 MB/s  0:00:03m0:00:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.
